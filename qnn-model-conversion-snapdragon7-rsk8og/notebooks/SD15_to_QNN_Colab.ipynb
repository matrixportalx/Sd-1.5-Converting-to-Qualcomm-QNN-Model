# %% [markdown]
# <a href="https://colab.research.google.com/github/matrixportalx/Sd-1.5-Converting-to-Qualcomm-QNN-Model/blob/claude%2Fqnn-model-conversion-snapdragon7-rsk8og/qnn-model-conversion-snapdragon7-rsk8og/notebooks/SD15_to_QNN_Colab.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # SD 1.5 (.safetensors) → Qualcomm QNN `qnn2.39_min` — Colab
#
# Bir **safetensors indirme linki** girin → dönüştürün → **Hugging Face reponuza** yükleyin.
# Çıktı: `<isim>_qnn2.39_min.zip` (Ruya / Local Dream ile içe aktarılır).
#
# ### Önce oku (önemli):
# 1. **Runtime → Change runtime type → High-RAM** seçin. Ücretsiz katman (12 GB) 512px'te OOM olabilir; **Colab Pro / High-RAM (25–51 GB)** önerilir.
# 2. **QNN/QAIRT SDK otomatik indirilir** — `matrixportalx/qairt-sdk` **v2.39.0.250926** release'inden. Public olduğu için token gerekmez.
# 3. QAIRT araçları **Python 3.10** ister (Colab 3.12); 4. adım izole bir 3.10 ortamı kurar (otomatik).
# 4. HF token'ınızı Colab **Secrets** (🔑 sol menü) içine `HF_TOKEN` adıyla ekleyin (write izinli).
# 5. civitai linki token istiyorsa Secrets'a `CIVITAI_TOKEN` ekleyin.
#
# Hücreleri **sırayla** çalıştırın.

# %% [markdown]
# ## 1) Ayarlar (buradan doldurun)

# %%
#@title Dönüşüm ayarları { display-mode: "form" }
SAFETENSORS_URL = "https://civitai.com/api/download/models/413877?fileId=335971"  #@param {type:"string"}
MODEL_NAME = "CyberRealisticLCM"  #@param {type:"string"}
TIER = "min"  #@param ["min", "mid", "high"]
RESOLUTIONS = "512x512"  #@param ["512x512", "512x512,512x768,768x512"] {allow-input: true}

#@markdown **Gelişmiş / deneme** (normalde boş bırakın)
#@markdown - `DSP_ARCH`: hedef HTP mimarisi. Boş = tier varsayılanı (min→v69).
#@markdown   Cihazda yüklenmiyorsa **v68** deneyin (çalışan `_min` modeller muhtemelen v68).
#@markdown - `REBUILD_BIN`: kuantizasyonu TEKRARLAMADAN sadece .bin'leri yeniden üretir (~3 dk).
DSP_ARCH = ""  #@param ["", "v68", "v69", "v73", "v75"]
REBUILD_BIN = False  #@param {type:"boolean"}

#@markdown **Hugging Face yükleme modu**
#@markdown - *Ayrı repo*: her model kendi reposuna → `<kullanıcı>/MODEL_NAME`
#@markdown - *Koleksiyon*: hepsi tek repoda, her model alt klasörde → `<kullanıcı>/COLLECTION/MODEL_NAME/`
UPLOAD_MODE = "Ayri repo (model adiyla)"  #@param ["Ayri repo (model adiyla)", "Koleksiyon (tek repo)"]
COLLECTION_REPO = "sd_qnn"  #@param {type:"string"}
HF_REPO = ""  #@param {type:"string"}
HF_PRIVATE = False  #@param {type:"boolean"}
#@markdown (`HF_REPO` doldurulursa iki modu da geçersiz kılar; doğrudan o repoya yükler.)

#@markdown **QAIRT SDK release** (varsayılan sizin public release'iniz)
QAIRT_REPO = "matrixportalx/qairt-sdk"  #@param {type:"string"}
QAIRT_TAG = "v2.39.0.250926"  #@param {type:"string"}
QNN_VERSION = "2.39"  #@param {type:"string"}

import os
os.environ["QNN_VERSION"] = QNN_VERSION
os.environ["DSP_ARCH"] = DSP_ARCH            # bos = tier varsayilani
os.environ["REBUILD_BIN"] = "1" if REBUILD_BIN else "0"
assert SAFETENSORS_URL, "SAFETENSORS_URL boş olamaz"
print("Ayarlar tamam:", MODEL_NAME, TIER, RESOLUTIONS, "| qnn", QNN_VERSION)
print("DSP_ARCH =", DSP_ARCH or "(tier varsayilani)", "| REBUILD_BIN =", REBUILD_BIN)

# %% [markdown]
# ## 2) Depoyu çek + Python bağımlılıkları + MNN

# %%
# %cd /content
BR = "claude/qnn-model-conversion-snapdragon7-rsk8og"
URL = "https://github.com/matrixportalx/Sd-1.5-Converting-to-Qualcomm-QNN-Model.git"
# Klasor varsa en guncel kodu cek; yoksa klonla (re-run'da guncel requirements alinir)
# !if [ -d sd-qnn ]; then cd sd-qnn && git fetch -q origin $BR && git reset -q --hard origin/$BR && cd ..; else git clone -q --branch $BR $URL sd-qnn; fi
# %cd /content/sd-qnn
# !pip -q install -r requirements.txt
# MNN converter (text_encoder + vae -> .mnn) + onnx export/sadelestirme araclari
# !pip -q install MNN onnxscript onnxslim
import os
os.environ["MNNCONVERT"] = "mnnconvert"
print("OK")
# Out:
# /content
# /content/sd-qnn
# OK

# %% [markdown]
# ## 2b) (Teşhis) Çalışan resmi bir `_min` modelin içindeki dosya yapısını göster
#
# Bu hücre, referans bir modeli indirip **içindeki dosya listesini** yazar. Çıktıyı paylaşırsan paketleme (`05_package.py`) birebir buna göre düzeltilir. `HF_TOKEN` gerekmez (repo public ise).

# %%
#@title Referans modelin dosya yapısını göster (teşhis)
REF_REPO = "Mr-J-369/AbyssOrangeMix3-SD1.5-qnn2.28"  #@param {type:"string"}
import os, zipfile
from huggingface_hub import HfApi, hf_hub_download
try:
    from google.colab import userdata
    t = userdata.get("HF_TOKEN")
    if t: os.environ["HF_TOKEN"] = t
except Exception:
    pass
tok = os.environ.get("HF_TOKEN")

api = HfApi(token=tok)
files = api.list_repo_files(REF_REPO)
print("REPO DOSYALARI:", files)
zips = [f for f in files if f.endswith(".zip")]
if not zips:
    print("\n[!] Repo'da zip yok. Dosyalar zaten acik olabilir (yukaridaki liste).")
else:
    target = next((z for z in zips if "min" in z.lower()), zips[0])
    print("\nIndiriliyor (icini gormek icin):", target)
    p = hf_hub_download(REF_REPO, target, token=tok)
    with zipfile.ZipFile(p) as zf:
        print(f"\n=== {target} ICERIGI ===")
        for n in zf.namelist():
            print(f"  {n}   ({zf.getinfo(n).file_size} bytes)")
print("\n>>> Bu ciktinin TAMAMINI paylas; paketleme buna gore duzeltilecek.")

# %% [markdown]
# ## 3) (İsteğe bağlı) Swap ekle — düşük RAM'de OOM'u azaltır

# %%
#@title 16 GB swap oluştur (ücretsiz katmanda önerilir)
# !fallocate -l 16G /content/swapfile 2>/dev/null || dd if=/dev/zero of=/content/swapfile bs=1M count=16384
# !chmod 600 /content/swapfile && mkswap /content/swapfile && swapon /content/swapfile
# !free -h

# %% [markdown]
# ## 4) QAIRT 2.39 SDK'yı indir + Python 3.10 ortamını kur (otomatik)
#
# SDK release'ten iner; QAIRT araçları için izole bir Python 3.10 venv + libc++ kurulur. Release private ise Colab Secrets'a `GH_TOKEN` ekleyin (public ise gerekmez).

# %%
import os
try:
    from google.colab import userdata
    for k in ("GH_TOKEN", "GITHUB_TOKEN"):
        try:
            v = userdata.get(k)
            if v: os.environ["GH_TOKEN"] = v
        except Exception:
            pass
except Exception:
    pass

# !python scripts/setup_qnn_sdk.py --repo "$QAIRT_REPO" --tag "$QAIRT_TAG" --dest /content/qairt | tee /content/sdk_setup.log

root = None
for line in open("/content/sdk_setup.log"):
    if line.startswith("QNN_SDK_ROOT="):
        root = line.strip().split("=", 1)[1]
assert root, "QNN_SDK_ROOT bulunamadı — 4. adım loguna bakın."
os.environ["QNN_SDK_ROOT"] = root
print("QNN_SDK_ROOT =", root)

# QAIRT python konvertorleri Python 3.10 + libc++ ister -> izole venv kur
# !chmod +x scripts/*.sh
# !bash scripts/setup_qnn_python.sh
if os.path.exists("/content/qnn_py.path"):
    os.environ["QNN_PYTHON"] = open("/content/qnn_py.path").read().strip()
    print("QNN_PYTHON =", os.environ["QNN_PYTHON"])

# %%
#@title 4b) TEŞHİS: Çalışan referans modelin gerçek tensör tiplerini dök
#@markdown Uygulama UNet'e `uint16` latent + `int32` timestep yazıyor.
#@markdown Bu hücre çalışan bir referansın **gerçek** dtype'larını gösterir →
#@markdown ona göre üretiriz. (4. adımdan SONRA çalıştırın; SDK gerekli.)
REF_REPO = "Mr-J-369/AbyssOrangeMix3-SD1.5-qnn2.28"  #@param {type:"string"}
import os
try:
    from google.colab import userdata
    t = userdata.get("HF_TOKEN")
    if t: os.environ["HF_TOKEN"] = t
except Exception:
    pass
os.environ["REF_REPO"] = REF_REPO
# !chmod +x scripts/*.sh
# !bash scripts/inspect_reference.sh

# %% [markdown]
# ## 5) Modeli indir (civitai / HF / düz link)

# %%
import os
try:
    from google.colab import userdata
    for k in ("CIVITAI_TOKEN", "HF_TOKEN"):
        try:
            v = userdata.get(k)
            if v: os.environ[k] = v
        except Exception:
            pass
except Exception:
    pass

# !python scripts/fetch_model.py --url "$SAFETENSORS_URL" --output work/input.safetensors

# %% [markdown]
# ## 6) Dönüştür (uçtan uca)
#
# **Uyarı:** En uzun adım — UNet + VAE kuantizasyonu ~25-30 dk sürebilir.
# Sekmeyi açık tutun. (`REBUILD_BIN` işaretliyse sadece .bin'ler ~3 dk'da yenilenir.)

# %%
import os
os.environ["DSP_ARCH"] = DSP_ARCH
os.environ["REBUILD_BIN"] = "1" if REBUILD_BIN else "0"
print("DSP_ARCH =", DSP_ARCH or "(tier varsayilani -> min=v68)",
      "| REBUILD_BIN =", REBUILD_BIN)

# !chmod +x convert_all.sh scripts/*.sh
# !./convert_all.sh work/input.safetensors "$MODEL_NAME" "$TIER" "$RESOLUTIONS"

import glob
print("Üretilen:", glob.glob("dist/*.zip"))
# Out:
# DSP_ARCH = (tier varsayilani -> min=v68) | REBUILD_BIN = False
# [*] DSP_ARCH override = v68
# ### 0) safetensors -> diffusers [ATLANDI]
# ### 1) ONNX/emb export (v11)
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# Flax classes are deprecated and will be removed in Diffusers v0.40.0. We recommend migrating to PyTorch classes or pinning your version of Diffusers.
# [*] Pipeline yukleniyor: work/CyberRealisticLCM/pipeline
# Keyword arguments {'load_safety_checker': False} are not expected by StableDiffusionPipeline and will be ignored.
# Loading pipeline components...:   0% 0/6 [00:00<?, ?it/s]
# Loading weights: 100% 196/196 [00:00<00:00, 5373.24it/s]
# Loading pipeline components...: 100% 6/6 [00:00<00:00, 11.97it/s]
# You have disabled the safety checker for <class 'diffusers.pipelines.stable_diffusion.pipeline_stable_diffusion.StableDiffusionPipeline'> by passing `safety_checker=None`. Ensure that you abide to the conditions of the Stable Diffusion license and do not expose unfiltered results in services or applications open to the public. Both the diffusers team and Hugging Face strongly recommend to keep the safety filter enabled in all public facing circumstances, disabling it only for use-cases that involve analyzing network behavior or auditing its results. For more information, please have a look at https://github.com/huggingface/diffusers/pull/254 .
# Loading weights: 100% 196/196 [00:00<00:00, 4500.23it/s]
#     [clip] eager attention ile yuklendi (IsNaN onlenir)
# [*] token_emb.bin  (49408, 768) fp32 -> work/CyberRealisticLCM/onnx/token_emb.bin (144 MB)
# [*] pos_emb.bin    (77, 768) fp32 -> work/CyberRealisticLCM/onnx/pos_emb.bin (236544 B)
# [*] clip_v2 -> work/CyberRealisticLCM/onnx/clip_v2.onnx
# /content/sd-qnn/scripts/01_export_onnx.py:36: DeprecationWarning: You are using the legacy TorchScript-based ONNX export. Starting in PyTorch 2.9, the new torch.export-based ONNX exporter has become the default. Learn more about the new export logic: https://docs.pytorch.org/docs/stable/onnx_export.html. For exporting control flow: https://pytorch.org/tutorials/beginner/onnx/export_control_flow_model_to_onnx_tutorial.html
#   return torch.onnx.export(*args, dynamo=False, **kwargs)
# /usr/local/lib/python3.12/dist-packages/transformers/masking_utils.py:637: TracerWarning: torch.tensor results are registered as constants in the trace. You can safely ignore this warning if you use this function to create tensors out of constant variables that would be the same every time you call this function. In any other case, this might cause the trace to be incorrect.
#   mask = torch.where(mask, torch.tensor(0.0, device=mask.device, dtype=dtype), min_dtype)
#     [onnxslim] sadelestirildi
# [*] clip (tam) -> work/CyberRealisticLCM/onnx/clip.onnx
# /usr/local/lib/python3.12/dist-packages/transformers/models/clip/modeling_clip.py:243: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if seq_length > max_position_embedding:
#     [onnxslim] sadelestirildi
# [*] vae_decoder -> work/CyberRealisticLCM/onnx/vae_decoder.onnx
# /usr/local/lib/python3.12/dist-packages/diffusers/models/upsampling.py:145: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /usr/local/lib/python3.12/dist-packages/diffusers/models/upsampling.py:160: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if hidden_states.shape[0] >= 64:
# /usr/local/lib/python3.12/dist-packages/diffusers/models/upsampling.py:171: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if hidden_states.numel() * scale_factor > pow(2, 31):
#     [onnxslim] sadelestirildi
# [*] vae_encoder -> work/CyberRealisticLCM/onnx/vae_encoder.onnx
# /usr/local/lib/python3.12/dist-packages/diffusers/models/downsampling.py:134: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /usr/local/lib/python3.12/dist-packages/diffusers/models/downsampling.py:143: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   assert hidden_states.shape[1] == self.channels
# /usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/torchscript_exporter/jit_utils.py:308: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /pytorch/torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_node_shape_type_inference(node, params_dict, opset_version)
# /usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/torchscript_exporter/utils.py:714: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /pytorch/torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
# /usr/local/lib/python3.12/dist-packages/torch/onnx/_internal/torchscript_exporter/utils.py:1187: UserWarning: Constant folding - Only steps=1 can be constant folded for opset >= 10 onnx::Slice op. Constant folding not applied. (Triggered internally at /pytorch/torch/csrc/jit/passes/onnx/constant_fold.cpp:178.)
#   _C._jit_pass_onnx_graph_shape_type_inference(
#     [onnxslim] sadelestirildi
# [*] unet 512x512 -> work/CyberRealisticLCM/onnx/unet_512x512.onnx
# /usr/local/lib/python3.12/dist-packages/diffusers/models/unets/unet_2d_condition.py:1050: TracerWarning: Converting a tensor to a Python boolean might cause the trace to be incorrect. We can't record the data flow of Python values, so this value will be treated as a constant in the future. This means that the trace might not generalize to other inputs!
#   if dim % default_overall_up_factor != 0:
# [*] tokenizer.json yazildi
# [+] ONNX/emb export tamam -> work/CyberRealisticLCM/onnx
#   [temizlik] mnn/ + qnn/build + vae bin'leri siliniyor (unet.bin korunuyor)
# ### 2) clip_v2 -> MNN
# ==> clip_v2.onnx -> clip_v2.mnn
# The device supports: i8sdot:0, fp16:0, i8mm: 0, sve2: 0, sme2: 0
# The device supports: i8sdot:0, fp16:0, i8mm: 0, sve2: 0, sme2: 0
# Start to Convert Other Model Format To MNN Model..., target version: 3.6
# [02:31:03] :46: ONNX Model ir version: 8
# [02:31:03] :47: ONNX Model opset version: 17
# Start to Optimize the MNN Net...
# inputTensors : [ input_embedding, ]
# outputTensors: [ last_hidden_state, ]
# Converted Success!
# ==> clip.onnx -> clip.mnn
# The device supports: i8sdot:0, fp16:0, i8mm: 0, sve2: 0, sme2: 0
# The device supports: i8sdot:0, fp16:0, i8mm: 0, sve2: 0, sme2: 0
# Start to Convert Other Model Format To MNN Model..., target version: 3.6
# [02:31:08] :46: ONNX Model ir version: 8
# [02:31:08] :47: ONNX Model opset version: 17
# Start to Optimize the MNN Net...
# inputTensors : [ input_ids, ]
# outputTensors: [ last_hidden_state, ]
# Converted Success!
# [+] MNN cikti -> ../work/CyberRealisticLCM/mnn
# ### 3) UNet kalibrasyon [ATLANDI]
# ### 4) UNet -> QNN (a16w8 + restrict steps, graf 'model')
# [+] HTP config yazildi (tier=min, dsp_arch=v68)
#     ana : ../work/CyberRealisticLCM/qnn/build/model/htp_min.json
#     ext : /content/sd-qnn/work/CyberRealisticLCM/qnn/build/model/htp_ext_min.json
#   [converter] ../work/CyberRealisticLCM/onnx/unet_512x512.onnx -> ../work/CyberRealisticLCM/qnn/build/model/model.dlc (graf: model)
# 2026-07-25 02:31:14,640 - 278 - INFO - INFO_INITIALIZATION_SUCCESS:
# 2026-07-25 02:31:14,735 - 283 - WARNING - Unable to register converter supported Operation [Inverse:Version 1] with your Onnx installation. Converter will bail if Model contains this Op.
# 2026-07-25 02:31:15,013 - 283 - WARNING - --desired_input_shape and -d are deprecated. Use --source_model_input_shape or -s for achieving this functionality
# 2026-07-25 02:31:15,014 - 278 - INFO - Input shape info
# 2026-07-25 02:31:54,329 - 283 - WARNING - Onnx model simplification failed due to: No module named 'onnxsim'
# 2026-07-25 02:31:54,329 - 283 - WARNING - Simplified model validation failed
# 2026-07-25 02:31:54,631 - 283 - WARNING - Onnx model simplification failed due to: No module named 'onnxsim'
# 2026-07-25 02:31:54,631 - 283 - WARNING - Simplified model validation failed
# 2026-07-25 02:31:54,772 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/time_proj/Cast will be interpreted at conversion time
# 2026-07-25 02:31:54,782 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/Cast will be interpreted at conversion time
# 2026-07-25 02:31:54,782 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:54,789 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:54,814 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:54,876 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.0/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:54,877 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.0/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:54,893 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.0/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:54,919 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.0/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:54,920 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.0/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:54,936 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.0/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:54,990 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:55,053 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.1/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:55,054 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.1/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:55,070 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.1/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:55,097 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.1/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:55,098 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.1/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:55,114 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.0/attentions.1/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:55,173 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:55,247 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.0/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:55,248 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.0/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:55,264 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.0/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:55,294 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.0/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:55,295 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.0/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:55,311 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.0/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:55,379 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:55,452 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.1/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:55,453 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.1/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:55,469 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.1/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:55,500 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.1/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:55,502 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.1/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:55,518 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.1/attentions.1/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:55,600 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:55,708 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.0/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:55,709 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.0/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:55,725 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.0/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:55,764 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.0/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:55,765 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.0/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:55,781 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.0/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:55,902 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:56,008 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.1/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:56,009 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.1/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:56,025 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.1/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:56,063 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.1/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:56,064 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.1/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:56,080 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/down_blocks.2/attentions.1/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:56,230 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:56,327 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:56,427 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:56,534 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/mid_block/attentions.0/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:56,535 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/mid_block/attentions.0/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:56,551 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/mid_block/attentions.0/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:56,590 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/mid_block/attentions.0/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:56,591 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/mid_block/attentions.0/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:56,607 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/mid_block/attentions.0/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:56,729 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:56,853 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:56,985 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:57,117 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:57,281 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:57,396 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.0/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:57,397 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.0/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:57,413 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.0/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:57,452 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.0/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:57,454 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.0/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:57,470 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.0/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:57,619 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:57,733 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.1/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:57,734 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.1/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:57,750 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.1/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:57,789 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.1/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:57,791 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.1/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:57,807 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.1/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:57,942 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:58,055 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.2/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:58,056 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.2/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:58,073 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.2/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:58,111 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.2/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:58,112 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.2/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:58,129 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.1/attentions.2/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:58,276 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:58,355 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.0/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:58,356 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.0/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:58,372 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.0/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:58,403 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.0/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:58,405 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.0/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:58,421 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.0/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:58,497 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:58,575 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.1/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:58,576 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.1/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:58,592 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.1/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:58,623 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.1/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:58,624 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.1/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:58,640 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.1/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:58,713 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:58,791 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.2/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:58,792 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.2/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:58,808 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.2/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:58,839 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.2/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:58,840 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.2/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:58,856 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.2/attentions.2/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:58,935 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:59,002 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.0/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:59,003 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.0/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:59,019 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.0/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:59,049 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.0/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:59,050 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.0/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:59,066 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.0/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:59,124 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:59,191 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.1/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:59,192 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.1/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:59,208 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.1/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:59,236 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.1/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:59,238 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.1/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:59,254 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.1/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:59,312 - 283 - WARNING - GEMM operation is not supported in the general case, attempting to interpret as FC
# 2026-07-25 02:31:59,378 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.2/transformer_blocks.0/attn1/Cast will be interpreted at conversion time
# 2026-07-25 02:31:59,380 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.2/transformer_blocks.0/attn1/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:59,396 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.2/transformer_blocks.0/attn1/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:59,424 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.2/transformer_blocks.0/attn2/Cast will be interpreted at conversion time
# 2026-07-25 02:31:59,425 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.2/transformer_blocks.0/attn2/Cast_1 will be interpreted at conversion time
# 2026-07-25 02:31:59,441 - 283 - WARNING - Only numerical type cast is supported. The cast op: /unet/up_blocks.3/attentions.2/transformer_blocks.0/attn2/Cast_2 will be interpreted at conversion time
# 2026-07-25 02:31:59,903 - 283 - WARNING - Unused Input nodes found: []
# 2026-07-25 02:32:25,253 - 283 - WARNING - Unused Input nodes found: []
# 2026-07-25 02:32:25,266 - 278 - INFO - INFO_INITIALIZATION_SUCCESS:
# 2026-07-25 02:32:34,341 - 278 - INFO - INFO_CONVERSION_SUCCESS: Conversion completed successfully
# 2026-07-25 02:32:34,343 - 278 - INFO - INFO_WRITE_SUCCESS:
#   [quantizer] a16w8 kalibrasyon
#     [restrict] -0x8000 0x7F7F
# 2026-07-25 02:32:37,456 - 283 - WARNING - Restrict_quantization_steps is only supported for --param_quantizer = symmetric or per channel/row quantization. Value will be ignored.
# IrQuantizer: Param Quantizer should be set to symmetric for 32 bit biases. Will ignore param quantizer option: min-max for biases
#      0.3ms [  INFO ] Inferences will run in sync mode
# Processing inference input(s):
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0000.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0000.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0000.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0001.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0001.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0001.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0002.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0002.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0002.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0003.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0003.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0003.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0004.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0004.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0004.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0005.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0005.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0005.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0006.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0006.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0006.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0007.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0007.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0007.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0008.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0008.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0008.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0009.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0009.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0009.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0010.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0010.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0010.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0011.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0011.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0011.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0012.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0012.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0012.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0013.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0013.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0013.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0014.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0014.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0014.raw
# sample -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/sample_0015.raw
# timestamp -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/timestep_0015.raw
# text_embedding -> /content/sd-qnn/work/CyberRealisticLCM/calib/512x512/ehs_0015.raw
#      0.6ms [  INFO ] No BackendExtensions lib provided;initializing NetRunBackend Interface
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation start
#      0.3ms [  INFO ] [QNN_CPU] CpuBackend creation end
#      0.9ms [WARNING] Unable to find a device with NetRunDeviceKeyDefault in Library NetRunBackendLibKeyDefault
#      0.9ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create start
#      0.3ms [  INFO ] [QNN_CPU] QnnContext create end
#      1.1ms [  INFO ] Entering QuantizeRuntimeApp flow
#      1.2ms [WARNING] Profile Logger with name = defaultKey doesn't exist! Returning nullptr
#      0.6ms [  INFO ] [QNN_CPU] CpuGraph creation start
#      0.6ms [  INFO ] [QNN_CPU] CpuGraph creation end
#      0.6ms [  INFO ] [QNN_CPU] QnnGraph create end
#   2195.8ms [  INFO ] [QNN_CPU] QnnGraph finalize start
#   3626.9ms [  INFO ] [QNN_CPU] QnnGraph finalize end
#   3629.1ms [  INFO ] [QNN_CPU] QnnGraph execute start
#  32849.7ms [  INFO ] [QNN_CPU] QnnGraph execute end
#  32849.5ms [  INFO ] cleaning up resources for input tensors
#  32849.6ms [  INFO ] cleaning up resources for output tensors
#  32850.9ms [  INFO ] [QNN_CPU] QnnGraph execute start
#  60586.1ms [  INFO ] [QNN_CPU] QnnGraph execute end
#  60585.7ms [  INFO ] cleaning up resources for input tensors
#  60585.7ms [  INFO ] cleaning up resources for output tensors
#  60587.0ms [  INFO ] [QNN_CPU] QnnGraph execute start
#  88075.6ms [  INFO ] [QNN_CPU] QnnGraph execute end
#  88075.2ms [  INFO ] cleaning up resources for input tensors
#  88075.3ms [  INFO ] cleaning up resources for output tensors
#  88076.5ms [  INFO ] [QNN_CPU] QnnGraph execute start
# 115779.3ms [  INFO ] [QNN_CPU] QnnGraph execute end
# 115778.8ms [  INFO ] cleaning up resources for input tensors
# 115778.8ms [  INFO ] cleaning up resources for output tensors
# 115780.1ms [  INFO ] [QNN_CPU] QnnGraph execute start
# 143531.4ms [  INFO ] [QNN_CPU] QnnGraph execute end
# 143531.0ms [  INFO ] cleaning up resources for input tensors
# 143531.0ms [  INFO ] cleaning up resources for output tensors
# 143532.3ms [  INFO ] [QNN_CPU] QnnGraph execute start
# 171058.9ms [  INFO ] [QNN_CPU] QnnGraph execute end
# 171058.5ms [  INFO ] cleaning up resources for input tensors
# 171058.5ms [  INFO ] cleaning up resources for output tensors
# 171059.7ms [  INFO ] [QNN_CPU] QnnGraph execute start
# 198690.0ms [  INFO ] [QNN_CPU] QnnGraph execute end
# 198689.7ms [  INFO ] cleaning up resources for input tensors
# 198689.7ms [  INFO ] cleaning up resources for output tensors
# 198690.9ms [  INFO ] [QNN_CPU] QnnGraph execute start

# %% [markdown]
# ## 7) Hugging Face'e yükle
#
# `HF_REPO` boşsa, **model isminden otomatik repo** oluşturulur: `<kullanıcı_adın>/MODEL_NAME` — ve model oraya yüklenir (küçük bir model kartıyla). Belirli bir repoya yüklemek istersen `HF_REPO` alanını doldur. Gerekli: Colab Secrets'ta write izinli `HF_TOKEN`.

# %%
import glob, os
zips = sorted(glob.glob("dist/*.zip"))
assert zips, "dist/ içinde zip yok — 6. adım başarısız olmuş olabilir."
zip_path = zips[-1]

# HF_TOKEN'i Secrets'tan al (yazma izinli olmalı)
try:
    from google.colab import userdata
    t = userdata.get("HF_TOKEN")
    if t:
        os.environ["HF_TOKEN"] = t
except Exception:
    pass

priv = "--private" if HF_PRIVATE else ""
if HF_REPO.strip():
    # Doğrudan verilen repoya yükle
    cmd = f'python scripts/upload_hf.py --repo "{HF_REPO}" --name "{MODEL_NAME}" --file "{zip_path}" {priv}'
elif UPLOAD_MODE.startswith("Koleksiyon"):
    # MOD B: tek koleksiyon reposu, her model alt klasörde
    cmd = f'python scripts/upload_hf.py --collection "{COLLECTION_REPO}" --name "{MODEL_NAME}" --file "{zip_path}" {priv}'
else:
    # MOD A: model adından ayrı repo
    cmd = f'python scripts/upload_hf.py --name "{MODEL_NAME}" --file "{zip_path}" {priv}'
print(">", cmd)
os.system(cmd)
print("ZIP:", zip_path)
# Out:
# ---------------------------------------------------------------------------
# AssertionError                            Traceback (most recent call last)
# /tmp/ipykernel_8879/30969497.py in <cell line: 0>()
#       1 import glob, os
#       2 zips = sorted(glob.glob("dist/*.zip"))
# ----> 3 assert zips, "dist/ içinde zip yok — 6. adım başarısız olmuş olabilir."
#       4 zip_path = zips[-1]
#       5
#
# AssertionError: dist/ içinde zip yok — 6. adım başarısız olmuş olabilir.

# %% [markdown]
# ## 8) (İsteğe bağlı) ZIP'i doğrudan bilgisayara indir

# %%
from google.colab import files
import glob
zips = sorted(glob.glob("dist/*.zip"))
if zips:
    files.download(zips[-1])
